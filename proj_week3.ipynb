# %%
import pandas as pd
import numpy as  np

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Indian_Climate_Dataset_2024_2025 (1).csv")

# %%
Date = df["Date"].to_numpy()
print(Date)
# Out:
# ['2024-01-01' '2024-01-01' '2024-01-01' ... '2025-12-31' '2025-12-31'
#  '2025-12-31']

# %%
City = df["City"].to_numpy()
print(City)
# Out:
# ['Mumbai' 'Delhi' 'Bengaluru' ... 'Jaipur' 'Lucknow' 'Bhopal']

# %%
State = df["State"].to_numpy()
print(State)
# Out:
# ['Maharashtra' 'Delhi' 'Karnataka' ... 'Rajasthan' 'Uttar Pradesh'
#  'Madhya Pradesh']

# %%
Temperature_Max = df["Temperature_Max (°C)"].to_numpy()
print(Temperature_Max)
# Out:
# [32.5 25.4 37.2 ... 44.2 43.7 37.8]

# %%
Temperature_Min = df["Temperature_Min (°C)"].to_numpy()
print(Temperature_Min)
# Out:
# [18.  10.7 30.8 ... 37.6 35.3 25.8]

# %%
Temperature_Avg = df["Temperature_Avg (°C)"].to_numpy()
print(Temperature_Avg)
# Out:
# [25.2 18.1 34.  ... 40.9 39.5 31.8]

# %%
Humidity  = df["Humidity (%)"].to_numpy()
print(Humidity )
# Out:
# [77.6 84.1 49.  ... 74.8 50.3 53.7]

# %%
Rainfall = df["Rainfall (mm)"].to_numpy()
print(Rainfall)
# Out:
# [0.  0.  3.7 ... 1.2 0.  0. ]

# %%
Rainfall = df["Rainfall (mm)"].to_numpy()
print(Rainfall)
# Out:
# [0.  0.  3.7 ... 1.2 0.  0. ]

# %%
Wind_Speed = df["Wind_Speed (km/h)"].to_numpy()
print(Wind_Speed )
# Out:
# [ 3.3  9.   6.6 ... 20.5  7.3 24. ]

# %%
AQI = df["AQI"].to_numpy()
print(AQI)
# Out:
# [259 130  54 ... 329  80 157]

# %%
AQI_Category = df["AQI_Category"].to_numpy()
print(AQI_Category)
# Out:
# ['Poor' 'Moderate' 'Satisfactory' ... 'Very Poor' 'Satisfactory'
#  'Moderate']

# %%
Pressure = df["Pressure (hPa)"].to_numpy()
print(Pressure)
# Out:
# [1020.3 1008.4 1008.  ... 1006.4 1011.6  996.7]

# %%
Cloud_Cover= df["Cloud_Cover (%)"].to_numpy()
print(Cloud_Cover )
# Out:
# [62.1 46.  61.3 ... 80.  45.9 21.4]

# %%
df['Date'] = pd.to_datetime(df['Date'])
print("Date column converted to datetime.")
print(df['Date'].head())
# Out:
# Date column converted to datetime.
# 0   2024-01-01
# 1   2024-01-01
# 2   2024-01-01
# 3   2024-01-01
# 4   2024-01-01
# Name: Date, dtype: datetime64[ns]

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Date                    0
# City                    0
# State                   0
# Temperature_Max (°C)    0
# Temperature_Min (°C)    0
# Temperature_Avg (°C)    0
# Humidity (%)            0
# Rainfall (mm)           0
# Wind_Speed (km/h)       0
# AQI                     0
# AQI_Category            0
# Pressure (hPa)          0
# Cloud_Cover (%)         0
# dtype: int64

# %%
df['Month'] = df['Date'].dt.month
print("Month column extracted:")
print(df['Month'].head())
# Out:
# Month column extracted:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Month, dtype: int32

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Summer'
    elif month in [6, 7, 8, 9]:
        return 'Monsoon'
    else:
        return 'Post-Monsoon'

df['Season'] = df['Month'].apply(get_season)
print("Season column created:")
print(df[['Date', 'Month', 'Season']].head())
# Out:
# Season column created:
#         Date  Month  Season
# 0 2024-01-01      1  Winter
# 1 2024-01-01      1  Winter
# 2 2024-01-01      1  Winter
# 3 2024-01-01      1  Winter
# 4 2024-01-01      1  Winter

# %%
print("First 5 rows of the DataFrame:")
print(df.head())
# Out:
# First 5 rows of the DataFrame:
#         Date       City        State  Temperature_Max (°C)  \
# 0 2024-01-01     Mumbai  Maharashtra                  32.5
# 1 2024-01-01      Delhi        Delhi                  25.4
# 2 2024-01-01  Bengaluru    Karnataka                  37.2
# 3 2024-01-01    Chennai   Tamil Nadu                  37.2
# 4 2024-01-01    Kolkata  West Bengal                  27.4
#
#    Temperature_Min (°C)  Temperature_Avg (°C)  Humidity (%)  Rainfall (mm)  \
# 0                  18.0                  25.2          77.6            0.0
# 1                  10.7                  18.1          84.1            0.0
# 2                  30.8                  34.0          49.0            3.7
# 3                  30.4                  33.8          34.2            9.5
# 4                  17.5                  22.5          32.2            9.1
#
#    Wind_Speed (km/h)  AQI  AQI_Category  Pressure (hPa)  Cloud_Cover (%)  \
# ...

# %%
print("Concise summary of the DataFrame:")
df.info()
# Out:
# Concise summary of the DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7310 entries, 0 to 7309
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  7310 non-null   datetime64[ns]
#  1   City                  7310 non-null   object
#  2   State                 7310 non-null   object
#  3   Temperature_Max (°C)  7310 non-null   float64
#  4   Temperature_Min (°C)  7310 non-null   float64
#  5   Temperature_Avg (°C)  7310 non-null   float64
#  6   Humidity (%)          7310 non-null   float64
#  7   Rainfall (mm)         7310 non-null   float64
#  8   Wind_Speed (km/h)     7310 non-null   float64
#  9   AQI                   7310 non-null   int64
#  10  AQI_Category          7310 non-null   object
#  11  Pressure (hPa)        7310 non-null   float64
#  12  Cloud_Cover (%)       7310 non-null   float64
#  13  Month                 7310 non-null   int32
# ...

# %%
print("Descriptive statistics for all numerical columns:")
print(df.describe(include='all'))
# Out:
# Descriptive statistics for all numerical columns:
#                                  Date    City        State  \
# count                            7310    7310         7310
# unique                            NaN      10           10
# top                               NaN  Mumbai  Maharashtra
# freq                              NaN     731          731
# mean    2024-12-30 23:59:59.999999744     NaN          NaN
# min               2024-01-01 00:00:00     NaN          NaN
# 25%               2024-07-01 00:00:00     NaN          NaN
# 50%               2024-12-31 00:00:00     NaN          NaN
# 75%               2025-07-02 00:00:00     NaN          NaN
# max               2025-12-31 00:00:00     NaN          NaN
# std                               NaN     NaN          NaN
#
#         Temperature_Max (°C)  Temperature_Min (°C)  Temperature_Avg (°C)  \
# count            7310.000000           7310.000000           7310.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 7))
sns.lineplot(x='Date', y='Temperature_Avg (°C)', data=df)
plt.title('Daily Average Temperature Trend')
plt.xlabel('Date')
plt.ylabel('Average Temperature (°C)')
plt.grid(True)
plt.show()

# %%
df['Year'] = df['Date'].dt.year
monthly_avg_temp = df.groupby(['Year', 'Month'])['Temperature_Avg (°C)'].mean().reset_index()

plt.figure(figsize=(15, 7))
sns.lineplot(x='Month', y='Temperature_Avg (°C)', hue='Year', data=monthly_avg_temp, marker='o')
plt.title('Monthly Average Temperature Trend (2024-2025)')
plt.xlabel('Month')
plt.ylabel('Average Temperature (°C)')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.legend(title='Year')
plt.show()

# %%
seasonal_avg_rainfall = df.groupby('Season')['Rainfall (mm)'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Season', y='Rainfall (mm)', data=seasonal_avg_rainfall, palette='viridis')
plt.title('Average Rainfall per Season')
plt.xlabel('Season')
plt.ylabel('Average Rainfall (mm)')
plt.grid(axis='y')
plt.show()
# Out:
# /tmp/ipykernel_5047/1160258599.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Season', y='Rainfall (mm)', data=seasonal_avg_rainfall, palette='viridis')

# %%
seasonal_avg_rainfall = df.groupby('Season')['Rainfall (mm)'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Season', y='Rainfall (mm)', hue='Season', data=seasonal_avg_rainfall, palette='viridis', legend=False)
plt.title('Average Rainfall per Season')
plt.xlabel('Season')
plt.ylabel('Average Rainfall (mm)')
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with three subplots arranged in a 1x3 grid
plt.figure(figsize=(18, 5))

# Histogram for Maximum Temperature
plt.subplot(1, 3, 1) # 1 row, 3 columns, 1st subplot
sns.histplot(df['Temperature_Max (°C)'], kde=True, color='red')
plt.title('Distribution of Maximum Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')

# Histogram for Minimum Temperature
plt.subplot(1, 3, 2) # 1 row, 3 columns, 2nd subplot
sns.histplot(df['Temperature_Min (°C)'], kde=True, color='blue')
plt.title('Distribution of Minimum Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')

# Histogram for Average Temperature
plt.subplot(1, 3, 3) # 1 row, 3 columns, 3rd subplot
sns.histplot(df['Temperature_Avg (°C)'], kde=True, color='green')
plt.title('Distribution of Average Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')

# Adjust layout to prevent titles and labels from overlapping
plt.tight_layout()

# Display the plots
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 6))

# Scatter plot for Average Temperature vs. Humidity
plt.subplot(1, 2, 1) # 1 row, 2 columns, 1st subplot
sns.scatterplot(x='Temperature_Avg (°C)', y='Humidity (%)', data=df)
plt.title('Average Temperature vs. Humidity')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Humidity (%)')

# Scatter plot for Rainfall vs. Wind Speed
plt.subplot(1, 2, 2) # 1 row, 2 columns, 2nd subplot
sns.scatterplot(x='Rainfall (mm)', y='Wind_Speed (km/h)', data=df)
plt.title('Rainfall vs. Wind Speed')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Wind Speed (km/h)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get unique seasons
unique_seasons = df['Season'].unique()

# Determine the number of subplots needed
num_seasons = len(unique_seasons)
n_cols = 2  # Number of columns for subplots
n_rows = (num_seasons + n_cols - 1) // n_cols # Calculate rows needed

plt.figure(figsize=(n_cols * 7, n_rows * 6)) # Adjust figure size dynamically

for i, season in enumerate(unique_seasons):
    plt.subplot(n_rows, n_cols, i + 1)

    # Filter data for the current season
    season_df = df[df['Season'] == season]

    # Calculate AQI category distribution
    aqi_category_counts = season_df['AQI_Category'].value_counts()

    # Create pie chart
    plt.pie(aqi_category_counts, labels=aqi_category_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
    plt.title(f'AQI Category Distribution in {season}')
    plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.

plt.tight_layout()
plt.show()
